# %%
import pandas as pd
import numpy as np
import datetime

import duckdb

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.execute("DROP VIEW silver.dim_birth_date")
results = conn.execute("DROP VIEW silver.dim_term_begin_date")
results = conn.execute("DROP VIEW silver.dim_term_end_date")
results = conn.execute("DROP VIEW silver.dim_consultation_date")
results = conn.execute("DROP VIEW silver.dim_incident_date")
results = conn.execute("DROP VIEW silver.dim_payment_date")
results = conn.execute("DROP VIEW silver.dim_first_expense_date")
results = conn.execute("DROP VIEW silver.dim_month_cont_date")
conn.close()

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.execute("DROP TABLE governance.dim_screen")
conn.close()

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.execute("DROP TABLE bronze.dim_certificate")
conn.close()

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SHOW ALL TABLES").df()
conn.close()

print(results.shape)
display(results)
# Out:
# (26, 6)
#           database      schema                           name  \
# 0   insurance_case      bronze  bridge_consultation_diagnosis
# 1   insurance_case      bronze                dim_certificate
# 2   insurance_case      bronze                        dim_cie
# 3   insurance_case      bronze                     fact_claim
# 4   insurance_case      bronze              fact_consultation
# 5   insurance_case      bronze                      fact_term
# 6   insurance_case        gold               age_at_diagnosis
# 7   insurance_case        gold           customer_interaction
# 8   insurance_case  governance                     dim_screen
# 9   insurance_case  governance               fact_error_event
# 10  insurance_case  governance        fact_error_event_detail
# 11  insurance_case      silver  bridge_consultation_diagnosis
# 12  insurance_case      silver                 dim_birth_date
# 13  insurance_case      silver                dim_certificate
# 14  insurance_case      silver                        dim_cie
# 15  insurance_case      silver          dim_consultation_date
# 16  insurance_case      silver                       dim_date
# 17  insurance_case      silver         dim_first_expense_date
# 18  insurance_case      silver              dim_incident_date
# 19  insurance_case      silver            dim_month_cont_date
# 20  insurance_case      silver               dim_payment_date
# 21  insurance_case      silver            dim_term_begin_date
# 22  insurance_case      silver              dim_term_end_date
# 23  insurance_case      silver                     fact_claim
# 24  insurance_case      silver              fact_consultation
# 25  insurance_case      silver                      fact_term
#
#                                          column_names  \
# 0   [consultation_id, consultation_diagnosis_id, c...
# 1   [certificate_id, name, email, age, city, birth...
# 2                                  [cie_id, cie_name]
# 3   [claim_id, state, cie_id, diagnosis, incident_...
# 4   [consultation_id, certificate_id, consultation...
# 5   [term_id, certificate_id, term_begin_date, ter...
# 6   [surrogated_certificate_id, consultation_id, c...
# 7   [surrogated_certificate_id, certificate_number...
# 8   [screen_id, screen_type, screen_name, screen_d...
# 9                          [error_event_id, batch_id]
# 10  [error_event_id, batch_id, screen_id, error_ut...
# 11               [consultation_id, surrogated_cie_id]
# 12  [birth_date_id, date, date_type, day, month, y...
# 13  [surrogated_id, certificate_id, name, email, a...
# 14                  [surrogated_id, cie_id, cie_name]
# 15  [consultation_date_id, date, date_type, day, m...
# 16  [date_id, date, date_type, day, month, year, d...
# 17  [first_expense_date_id, date, date_type, day, ...
# 18  [incident_date_id, date, date_type, day, month...
# 19  [month_cont_date_id, date, date_type, day, mon...
# 20  [payment_date_id, date, date_type, day, month,...
# 21  [term_begin_date_id, date, date_type, day, mon...
# 22  [term_end_date_id, date, date_type, day, month...
# 23  [claim_id, state, surrogated_cie_id, incident_...
# 24  [consultation_id, surrogated_certificate_id, c...
# 25  [term_id, surrogated_certificate_id, term_begi...
#
#                                          column_types  temporary
# 0                  [BIGINT, BIGINT, VARCHAR, VARCHAR]      False
# 1   [BIGINT, VARCHAR, VARCHAR, BIGINT, VARCHAR, TI...      False
# 2                                  [VARCHAR, VARCHAR]      False
# 3   [VARCHAR, VARCHAR, VARCHAR, VARCHAR, TIMESTAMP...      False
# 4   [BIGINT, BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT...      False
# 5   [BIGINT, BIGINT, TIMESTAMP_NS, TIMESTAMP_NS, V...      False
# 6   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP_N...      False
# 7        [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]      False
# 8        [BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]      False
# 9                                  [INTEGER, INTEGER]      False
# 10  [INTEGER, INTEGER, INTEGER, TIMESTAMP, VARCHAR...      False
# 11                                   [BIGINT, BIGINT]      False
# 12  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 13  [BIGINT, BIGINT, VARCHAR, VARCHAR, BIGINT, VAR...      False
# 14                         [BIGINT, VARCHAR, VARCHAR]      False
# 15  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 16  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 17  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 18  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 19  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 20  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 21  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 22  [BIGINT, TIMESTAMP_NS, VARCHAR, BIGINT, BIGINT...      False
# 23  [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, BIG...      False
# 24  [BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT, VARC...      False
# 25          [BIGINT, BIGINT, BIGINT, BIGINT, VARCHAR]      False

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SELECT * FROM silver.dim_date").df()
conn.close()

display(results.head(6))
display(results.tail(6))
# Out:
#     date_id       date         date_type  day  month  year  day_of_week  \
# 0  19000101 1900-01-01  Fecha Disponible    1      1  1900            1
# 1  19250101 1925-01-01  Fecha Disponible    1      1  1925            4
# 2  19250102 1925-01-02  Fecha Disponible    2      1  1925            5
# 3  19250103 1925-01-03  Fecha Disponible    3      1  1925            6
# 4  19250104 1925-01-04  Fecha Disponible    4      1  1925            7
# 5  19250105 1925-01-05  Fecha Disponible    5      1  1925            1
#
#   day_name month_name  quarter weekday_indicator  week_of_year  \
# 0    Lunes      Enero        1      Entre Semana             1
# 1   Jueves      Enero        1      Entre Semana             1
# 2  Viernes      Enero        1      Entre Semana             1
# 3   Sábado      Enero        1     Fin de Semana             1
# 4  Domingo      Enero        1     Fin de Semana             1
# 5    Lunes      Enero        1      Entre Semana             2
#
#    is_end_of_month  is_end_of_quarter  is_end_of_year quarter_name year_month  \
# 0            False              False           False           T1    1900-01
# 1            False              False           False           T1    1925-01
# 2            False              False           False           T1    1925-01
# 3            False              False           False           T1    1925-01
# 4            False              False           False           T1    1925-01
# 5            False              False           False           T1    1925-01
#
#   quarter_year holiday_indicator
# 0      T1 1900        No Festivo
# 1      T1 1925        No Festivo
# 2      T1 1925        No Festivo
# 3      T1 1925        No Festivo
# 4      T1 1925        No Festivo
# 5      T1 1925        No Festivo
#         date_id       date         date_type  day  month  year  day_of_week  \
# 38351  20291231 2029-12-31  Fecha Disponible   31     12  2029            1
# 38352  22000101 2200-01-01  Fecha Disponible    1      1  2200            3
# 38353        -1        NaT         No Aplica    0      0     0            0
# 38354        -2        NaT     No Disponible    0      0     0            0
# 38355        -3        NaT       Por Definir    0      0     0            0
# 38356        -4        NaT    Fecha Inválida    0      0     0            0
#
#              day_name      month_name  quarter weekday_indicator  \
# 38351           Lunes       Diciembre        4      Entre Semana
# 38352       Miércoles           Enero        1      Entre Semana
# 38353       No Aplica       No Aplica        0         No Aplica
# 38354   No Disponible   No Disponible        0     No Disponible
# 38355     Por Definir     Por Definir        0       Por Definir
# 38356  Fecha Inválida  Fecha Inválida        0    Fecha Inválida
#
#        week_of_year  is_end_of_month  is_end_of_quarter  is_end_of_year  \
# 38351             1             True               True            True
# 38352             1            False              False           False
# 38353             0            False              False           False
# 38354             0            False              False           False
# 38355             0            False              False           False
# 38356             0            False              False           False
#
#          quarter_name year_month    quarter_year holiday_indicator
# 38351              T4    2029-12         T4 2029        No Festivo
# 38352              T1    2200-01         T1 2200        No Festivo
# 38353       No Aplica    0000-00       No Aplica         No Aplica
# 38354   No Disponible    0000-00   No Disponible     No Disponible
# 38355     Por Definir    0000-00     Por Definir       Por Definir
# 38356  Fecha Inválida    0000-00  Fecha Inválida    Fecha Inválida

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SELECT * FROM governance.dim_screen").df()
conn.close()

display(results.head(10))
# Out:
#    screen_id  screen_type                       screen_name  \
# 0          1     Columnar                        Valor nulo
# 1          2     Columnar          Valor fuera de intervalo
# 2          3  Estructural              Valor fuera de lista
# 3          4     Columnar  Cadena no compuesta por dígitos
# 4          5     Columnar      Fecha con formato incorrecto
# 5          6  Estructural                    Valor no único
# 6          7      Negocio        Valor menor que otro valor
#
#                  screen_description etl_module
# 0                        Valor nulo     v0.0.1
# 1          Valor fuera de intervalo     v0.0.1
# 2              Valor fuera de lista     v0.0.1
# 3  Cadena no compuesta por dígitos      v0.0.1
# 4      Fecha con formato incorrecto     v0.0.1
# 5                    Valor no único     v0.0.1
# 6        Valor menor que otro valor     v0.0.1

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SELECT * FROM governance.fact_error_event").df()
conn.close()

display(results.head(10))
# Out:
# Empty DataFrame
# Columns: [error_event_id, batch_id]
# Index: []

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SELECT * FROM governance.fact_error_event_detail").df()
conn.close()

display(results.head(10))
# Out:
# Empty DataFrame
# Columns: [error_event_id, batch_id, screen_id, error_utc_timestamp, table_name, column_name, record_identifier, original_value, replaced_value, error_condition]
# Index: []

# %%
conn = duckdb.connect('/home/armando/git/insurance_case/dagster-quickstart/insurance_case.db')
results = conn.sql("SELECT * FROM bronze.dim_certificate").df()
conn.close()

print(results.shape)
display(results.head(10))
# Out:
# (100, 8)
#    certificate_id                            name                      email  \
# 0               1           Luisa Carrera Barroso  eutropiobravo@example.com
# 1               2                 Cristian Murcia        cesar23@example.net
# 2               3                 Gala del Ortega       felipa93@example.com
# 3               4                Abraham Bejarano   roigmaricruz@example.com
# 4               5  María Dolores Mosquera-Barriga    tapiaafrica@example.org
# 5               6      Segismundo Ripoll Bermúdez     pinamarino@example.net
# 6               7       Clotilde Valverde Casares      claudia77@example.net
# 7               8          Amílcar España Salazar        adora51@example.org
# 8               9   Reynaldo Gilabert Quintanilla  roselloisaura@example.com
# 9              10                 Mamen Sáez Piña  antondionisia@example.com
#
#    age       city birth_date certificate_number gender
# 0   74   Zaragoza 1971-03-09             547829      M
# 1   55      Álava 1943-01-08             995112      M
# 2   63   Alicante 1947-01-29             138226      M
# 3   68  Salamanca 1952-08-31             312154      F
# 4   40     Huelva 1941-04-26             647930      M
# 5   71  Salamanca 1946-06-08             729300      F
# 6   53   Zaragoza 1944-10-12             819230      F
# 7   46    Segovia 1975-05-10             925814      F
# 8   67      Cádiz 1941-11-26             824060      F
# 9   51    Badajoz 1965-11-03             578807      F
